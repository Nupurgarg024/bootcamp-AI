# %%
import random

# Create a list of 10 random numbers
numbers = [random.randint(1, 100) for _ in range(10)]

print("Random numbers:", numbers)

# Print even numbers
print("Even numbers:")

for num in numbers:
    if num % 2 == 0:
        print(num)
# Out:
# Random numbers: [65, 16, 28, 80, 12, 71, 65, 83, 53, 43]
# Even numbers:
# 16
# 28
# 80
# 12

# %%
string = input("Enter a string: ")

# Reverse the complete string
print("Reverse of string:", string[::-1])

# Reverse the order of words
words = string.split()
print("Reverse of words:", " ".join(words[::-1]))
# Out:
# Enter a string:  HI MY NAME IS NUPUR GARG
# Reverse of string: GRAG RUPUN SI EMAN YM IH
# Reverse of words: GARG NUPUR IS NAME MY HI
